# %% [markdown]
# # Time Series Analysis of Accelerometer Sensor

# %% [markdown]
# ### Importing Libraries

# %%
# !pip install ts2vg
# !pip install igraph
# !pip install pycairo
# !pip install cairocffi

# %%
from ts2vg import NaturalVG
import numpy as np
import pandas as pd
import seaborn as sns
from seaborn.relational import relplot
import os
from ts2vg import HorizontalVG
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Task 1

# %% [markdown]
# ### WALKING

# %%
# Creating a Data Frame to capture all the results
results = pd.DataFrame(columns = ['Method', 'Subject', 'Sensor', 'Accelerometer Axis', 'Average degree', 'Network Diameter', 'Average Path Length', 'Activity'])

# %%
# Calcualting the HVG and NVG for Walking dataset for all 15 subjects and sensors

# Defining the current directory
# %cd '/content/drive/MyDrive/ClassFiles/project2/Walking'
dir = '/content/drive/MyDrive/ClassFiles/project2/Walking'

# Reading files one by one
for file in sorted(os.listdir(dir)):
  df = pd.read_csv(file, header=None)
  df.columns = ['id','Time', 'x', 'y', 'z']
  x = str(file).split("_")
  Sub = x[0]
  Sensor = x[1]
  
  # Taking only 1024 samples for analysis
  data = df.iloc[1000:2024,2:5]
  for col in data:
    ts = data[col]

    #NVG
    g = NaturalVG()
    g.build(ts)
    ig_g = g.as_igraph()

    results = results.append({"Method": 'NVG', "Subject": Sub, "Sensor": Sensor, "Accelerometer Axis": col, 'Average degree': np.mean(ig_g.degree()),
    'Network Diameter': ig_g.diameter(), 'Average Path Length': ig_g.average_path_length(), 'Activity': 'Walking'}, ignore_index=True)

    #HVG
    g = HorizontalVG()
    g.build(ts)
    ig = g.as_igraph()

    results = results.append({"Method": 'HVG', "Subject": Sub, "Sensor": Sensor, "Accelerometer Axis": col, 'Average degree': np.mean(ig.degree()),
    'Network Diameter': ig.diameter(), 'Average Path Length': ig.average_path_length(), 'Activity': 'Walking'}, ignore_index=True)
# Out:
# /content/drive/MyDrive/ClassFiles/project2/Walking

# %% [markdown]
# ### RUNNING

# %%
# Calcualting the HVG and NVG for Running dataset for all 15 subjects and sensors

# Defining the current directory
# %cd '/content/drive/MyDrive/ClassFiles/project2/Running'
dir = '/content/drive/MyDrive/ClassFiles/project2/Running'

# Reading files one by one
for file in sorted(os.listdir(dir)):
  df = pd.read_csv(file, header=None)
  df.columns = ['id','Time', 'x', 'y', 'z']
  x = str(file).split("_")
  Sub = x[0]
  Sensor = x[1]
  
  # Taking only 1024 samples for analysis
  data = df.iloc[1000:2024,2:5]
  for col in data:
    ts = data[col]

    #NVG
    g = NaturalVG()
    g.build(ts)
    ig_g = g.as_igraph()

    results = results.append({"Method": 'NVG', "Subject": Sub, "Sensor": Sensor, "Accelerometer Axis": col, 'Average degree': np.mean(ig_g.degree()),
    'Network Diameter': ig_g.diameter(), 'Average Path Length': ig_g.average_path_length(), 'Activity': 'Running'}, ignore_index=True)

    #HVG
    g = HorizontalVG()
    g.build(ts)
    ig = g.as_igraph()

    results = results.append({"Method": 'HVG', "Subject": Sub, "Sensor": Sensor, "Accelerometer Axis": col, 'Average degree': np.mean(ig.degree()),
    'Network Diameter': ig.diameter(), 'Average Path Length': ig.average_path_length(), 'Activity': 'Running'}, ignore_index=True)
# Out:
# /content/drive/MyDrive/ClassFiles/project2/Running

# %% [markdown]
# ### CLIMBING UP

# %%
# Calcualting the HVG and NVG for Climbing Up dataset for all 15 subjects and sensors

# Defining the current directory
# %cd '/content/drive/MyDrive/ClassFiles/project2/ClimbUp'
dir = '/content/drive/MyDrive/ClassFiles/project2/ClimbUp'

# Reading files one by one
for file in sorted(os.listdir(dir)):
  df = pd.read_csv(file, header=None)
  df.columns = ['id','Time', 'x', 'y', 'z']
  x = str(file).split("_")
  Sub = x[0]
  Sensor = x[1]
  
  # Taking only 1024 samples for analysis
  data = df.iloc[1000:2024,2:5]
  for col in data:
    ts = data[col]

    #NVG
    g = NaturalVG()
    g.build(ts)
    ig_g = g.as_igraph()

    results = results.append({"Method": 'NVG', "Subject": Sub, "Sensor": Sensor, "Accelerometer Axis": col, 'Average degree': np.mean(ig_g.degree()),
    'Network Diameter': ig_g.diameter(), 'Average Path Length': ig_g.average_path_length(), 'Activity': 'Climbing Up'}, ignore_index=True)

    #HVG
    g = HorizontalVG()
    g.build(ts)
    ig = g.as_igraph()

    results = results.append({"Method": 'HVG', "Subject": Sub, "Sensor": Sensor, "Accelerometer Axis": col, 'Average degree': np.mean(ig.degree()),
    'Network Diameter': ig.diameter(), 'Average Path Length': ig.average_path_length(), 'Activity': 'Climbing Up'}, ignore_index=True)
# Out:
# /content/drive/MyDrive/ClassFiles/project2/ClimbUp

# %% [markdown]
# ### CLIMBING DOWN

# %%
# Calcualting the HVG and NVG for Climbing Down dataset for all 15 subjects and sensors

# Defining the current directory
# %cd '/content/drive/MyDrive/ClassFiles/project2/ClimbDown'
dir = '/content/drive/MyDrive/ClassFiles/project2/ClimbDown'

# Reading files one by one
for file in sorted(os.listdir(dir)):
  df = pd.read_csv(file, header=None)
  df.columns = ['id','Time', 'x', 'y', 'z']
  x = str(file).split("_")
  Sub = x[0]
  Sensor = x[1]
  
  # Taking only 1024 samples for analysis
  data = df.iloc[1000:2024,2:5]
  for col in data:
    ts = data[col]

    #NVG
    g = NaturalVG()
    g.build(ts)
    ig_g = g.as_igraph()

    results = results.append({"Method": 'NVG', "Subject": Sub, "Sensor": Sensor, "Accelerometer Axis": col, 'Average degree': np.mean(ig_g.degree()),
    'Network Diameter': ig_g.diameter(), 'Average Path Length': ig_g.average_path_length(), 'Activity': 'Climbing Down'}, ignore_index=True)

    #HVG
    g = HorizontalVG()
    g.build(ts)
    ig = g.as_igraph()

    results = results.append({"Method": 'HVG', "Subject": Sub, "Sensor": Sensor, "Accelerometer Axis": col, 'Average degree': np.mean(ig.degree()),
    'Network Diameter': ig.diameter(), 'Average Path Length': ig.average_path_length(), 'Activity': 'Climbing Down'}, ignore_index=True)
# Out:
# /content/drive/MyDrive/ClassFiles/project2/ClimbDown

# %% [markdown]
# ### Scatter Plots

# %% [markdown]
# ####Running & Walking

# %% [markdown]
# ##### X- Axis

# %%
# Slicing the resultant dataset for only Running and Walking Activities
Run_Walk = results[(results['Activity'] == 'Walking') | (results['Activity'] == 'Running')]

# Plotting the scatterplot with considering only X-Axis 
sns.relplot(x= 'Average degree', y = 'Network Diameter', hue='Activity', row = 'Sensor', col='Method', 
            data = Run_Walk[Run_Walk['Accelerometer Axis'] == 'x'], height=5)

# %% [markdown]
# #####Y - Axis

# %%
# Plotting the scatterplot with considering only Y-Axis 
sns.relplot(x= 'Average degree', y = 'Network Diameter', hue='Activity', row = 'Sensor', col='Method', 
            data = Run_Walk[Run_Walk['Accelerometer Axis'] == 'y'], height=5)

# %% [markdown]
# ##### Z -Axis

# %%
# Plotting the scatterplot with considering only Z-Axis 
sns.relplot(x= 'Average degree', y = 'Network Diameter', hue='Activity', row = 'Sensor', col='Method', 
            data = Run_Walk[Run_Walk['Accelerometer Axis'] == 'z'], height=5)

# %% [markdown]
# #### Climbing Up & Climbing *Down*

# %% [markdown]
# ##### X - Axis

# %%
# Slicing the resultant dataset for only Climbing Up and Climbing Down Activities
ClimbUp_Down = results[(results['Activity'] == 'Climbing Up') | (results['Activity'] == 'Climbing Down')]

# Plotting the scatterplot considering only X-Axis 
sns.relplot(x= 'Average degree', y = 'Network Diameter', hue='Activity', row = 'Sensor', col='Method',
            data = ClimbUp_Down[ClimbUp_Down['Accelerometer Axis'] == 'x'], height=5)

# %% [markdown]
# ##### Y - Axis

# %%
# Plotting the scatterplot considering only Y-Axis 
sns.relplot(x= 'Average degree', y = 'Network Diameter', hue='Activity', row = 'Sensor', col='Method',
            data = ClimbUp_Down[ClimbUp_Down['Accelerometer Axis'] == 'y'], height=5)

# %% [markdown]
# ##### Z - Axis

# %%
# Plotting the scatterplot considering only Z-Axis 
sns.relplot(x= 'Average degree', y = 'Network Diameter', hue='Activity', row = 'Sensor', col='Method',
            data = ClimbUp_Down[ClimbUp_Down['Accelerometer Axis'] == 'z'], height=5)

# %% [markdown]
# ##Task 2

# %% [markdown]
# ### Entropy function

# %%
# Essential functions needed to calculate Permutation Entropy
''' This module has essential functions supporting
fast and effective computation of permutation entropy and
its different variations.'''
import numpy as np


def s_entropy(freq_list):
    ''' This function computes the shannon entropy of a given frequency distribution.
    USAGE: shannon_entropy(freq_list)
    ARGS: freq_list = Numeric vector representing the frequency distribution
    OUTPUT: A numeric value representing shannon's entropy'''
    freq_list = [element for element in freq_list if element != 0]
    sh_entropy = 0.0
    for freq in freq_list:
        sh_entropy += freq * np.log(freq)
    sh_entropy = -sh_entropy
    return(sh_entropy)

def ordinal_patterns(ts, embdim, embdelay):
    ''' This function computes the ordinal patterns of a time series for a given embedding dimension and embedding delay.
    USAGE: ordinal_patterns(ts, embdim, embdelay)
    ARGS: ts = Numeric vector representing the time series, embdim = embedding dimension (3<=embdim<=7 prefered range), embdelay =  embdding delay
    OUPTUT: A numeric vector representing frequencies of ordinal patterns'''
    m, t = embdim, embdelay
    x = ts if isinstance(ts, np.ndarray) else np.array(ts) 

    tmp = np.zeros((x.shape[0], m))
    for i in range(m):
        tmp[:, i] = np.roll(x, i*t)
    partition = tmp[(t*m-1):, :] 
    permutation = np.argsort(partition)
    idx = _hash(permutation)

    counts = np.zeros(np.math.factorial(m))
    for i in range(counts.shape[0]):
        counts[i] = (idx == i).sum()
    return list(counts[counts != 0].astype(int))

def _hash(x):
    m, n = x.shape
    if n == 1:
        return np.zeros(m)
    return np.sum(np.apply_along_axis(lambda y: y < x[:, 0], 0, x), axis=1) * np.math.factorial(n-1) + _hash(x[:, 1:]) 
    

def p_entropy(op):
    ordinal_pat = op
    max_entropy = np.log(len(ordinal_pat))
    p = np.divide(np.array(ordinal_pat), float(sum(ordinal_pat)))
    return(s_entropy(p)/max_entropy)

def complexity(op):
    ''' This function computes the complexity of a time series defined as: Comp_JS = Q_o * JSdivergence * pe
    Q_o = Normalizing constant
    JSdivergence = Jensen-Shannon divergence
    pe = permutation entopry
    ARGS: ordinal pattern'''
    pe = p_entropy(op)
    constant1 = (0.5+((1 - 0.5)/len(op)))* np.log(0.5+((1 - 0.5)/len(op)))
    constant2 = ((1 - 0.5)/len(op))*np.log((1 - 0.5)/len(op))*(len(op) - 1)
    constant3 = 0.5*np.log(len(op))
    Q_o = -1/(constant1+constant2+constant3)

    temp_op_prob = np.divide(op, sum(op))
    temp_op_prob2 = (0.5*temp_op_prob)+(0.5*(1/len(op)))
    JSdivergence = (s_entropy(temp_op_prob2) - 0.5 * s_entropy(temp_op_prob) - 0.5 * np.log(len(op)))
    Comp_JS = Q_o * JSdivergence * pe
    return(Comp_JS)

def weighted_ordinal_patterns(ts, embdim, embdelay):
    m, t = embdim, embdelay
    x = ts if isinstance(ts, np.ndarray) else np.array(ts) 

    tmp = np.zeros((x.shape[0], m))
    for i in range(m):
        tmp[:, i] = np.roll(x, i*t)
    partition = tmp[(t*m-1):, :] 
    xm = np.mean(partition, axis=1)
    weight = np.mean((partition - xm[:, None])**2, axis=1)
    permutation = np.argsort(partition)
    idx = _hash(permutation)
    counts = np.zeros(np.math.factorial(m))
    for i in range(counts.shape[0]):
        counts[i] = sum(weight[i == idx])

    return list(counts[counts != 0])

# %% [markdown]
# ### Walking

# %%
# # Creating a Data Frame to capture all the results
Task2Results = pd.DataFrame(columns = ['Subject', 'Accelerometer Axis', 'Sensor', 'Signal Length', 'Dimension', 'Delay', 
                                       'Permutation Entropy', 'Complexity', 'Activity'])

# %%
# Calcualting the Entropy and Complexity for Walking dataset for all 15 subjects and sensors

# Defining the current directory
# %cd '/content/drive/MyDrive/ClassFiles/project2/Walking'
dir = '/content/drive/MyDrive/ClassFiles/project2/Walking'

# Reading files one by one 
for file in sorted(os.listdir(dir)):
  df = pd.read_csv(file, header=None)
  df.columns = ['id','Time', 'x', 'y', 'z']
  x = str(file).split("_")
  Sub = x[0]
  Sensor = x[1]
  
  for signal_length in [2024, 3048, 5096]:
    data = df.iloc[1000:signal_length,2:5]
    for col in data:
      ts = data[col]
      for de in range(1,4):
        for di in range(3,7):
          op = ordinal_patterns(ts, di, de)
          npe = p_entropy(op)
          ncomp = complexity(op)
          Task2Results = Task2Results.append({'Subject': Sub, 'Accelerometer Axis': col, 'Sensor': Sensor, 'Signal Length': signal_length - 1000, 'Dimension': di, 'Delay': de, 
                                       'Permutation Entropy': npe, 'Complexity': ncomp, 'Activity': 'Walking'}, ignore_index=True)
# Out:
# /content/drive/MyDrive/ClassFiles/project2/Walking

# %% [markdown]
# ### RUNNING

# %%
# Calcualting the Entropy and Complexity for Running dataset for all 15 subjects and sensors

# Defining the current directory
# %cd '/content/drive/MyDrive/ClassFiles/project2/Running'
dir = '/content/drive/MyDrive/ClassFiles/project2/Running'

# Reading files one by one 
for file in sorted(os.listdir(dir)):
  df = pd.read_csv(file, header=None)
  df.columns = ['id','Time', 'x', 'y', 'z']
  x = str(file).split("_")
  Sub = x[0]
  Sensor = x[1]
  for signal_length in [2024, 3048, 5096]:
    data = df.iloc[1000:signal_length,2:5]
    for col in data:
      ts = data[col]
      for de in range(1,4):
        for di in range(3,7):
          op = ordinal_patterns(ts, di, de)
          npe = p_entropy(op)
          ncomp = complexity(op)
          Task2Results = Task2Results.append({'Subject': Sub, 'Accelerometer Axis': col, 'Sensor': Sensor, 'Signal Length': signal_length - 1000, 'Dimension': di, 'Delay': de, 
                                       'Permutation Entropy': npe, 'Complexity': ncomp, 'Activity': 'Running'}, ignore_index=True)
# Out:
# /content/drive/MyDrive/ClassFiles/project2/Running

# %% [markdown]
# ### CLIMBING UP

# %%
# Calcualting the Entropy and Complexity for Climbing Up dataset for all 15 subjects and sensors

# Defining the current directory
# %cd '/content/drive/MyDrive/ClassFiles/project2/ClimbUp'
dir = '/content/drive/MyDrive/ClassFiles/project2/ClimbUp'

# Reading files one by one 
for file in sorted(os.listdir(dir)):
  df = pd.read_csv(file, header=None)
  df.columns = ['id','Time', 'x', 'y', 'z']
  x = str(file).split("_")
  Sub = x[0]
  Sensor = x[1]
  for signal_length in [2024, 3048, 5096]:
    data = df.iloc[1000:signal_length,2:5]
    for col in data:
      ts = data[col]
      for de in range(1,4):
        for di in range(3,7):
          op = ordinal_patterns(ts, di, de)
          npe = p_entropy(op)
          ncomp = complexity(op)
          Task2Results = Task2Results.append({'Subject': Sub, 'Accelerometer Axis': col, 'Sensor': Sensor, 'Signal Length': signal_length - 1000, 'Dimension': di, 'Delay': de, 
                                       'Permutation Entropy': npe, 'Complexity': ncomp, 'Activity': 'Climbing Up'}, ignore_index=True)
# Out:
# /content/drive/MyDrive/ClassFiles/project2/ClimbUp

# %% [markdown]
# ### CLIMBING DOWN

# %%
# Calcualting the Entropy and Complexity for Climbing Down dataset for all 15 subjects and sensors

# Defining the current directory
# %cd '/content/drive/MyDrive/ClassFiles/project2/ClimbDown'
dir = '/content/drive/MyDrive/ClassFiles/project2/ClimbDown'

# Reading files one by one 
for file in sorted(os.listdir(dir)):
  df = pd.read_csv(file, header=None)
  df.columns = ['id','Time', 'x', 'y', 'z']
  x = str(file).split("_")
  Sub = x[0]
  Sensor = x[1]
  for signal_length in [2024, 3048, 5096]:
    data = df.iloc[1000:signal_length,2:5]
    for col in data:
      ts = data[col]
      for de in range(1,4):
        for di in range(3,7):
          op = ordinal_patterns(ts, di, de)
          npe = p_entropy(op)
          ncomp = complexity(op)
          Task2Results = Task2Results.append({'Subject': Sub, 'Accelerometer Axis': col, 'Sensor': Sensor, 'Signal Length': signal_length - 1000, 'Dimension': di, 'Delay': de, 
                                       'Permutation Entropy': npe, 'Complexity': ncomp, 'Activity': 'Climbing Down'}, ignore_index=True)
# Out:
# /content/drive/MyDrive/ClassFiles/project2/ClimbDown

# %% [markdown]
# ### Scatter Plots

# %% [markdown]
# #### Running & Walking

# %% [markdown]
# ##### X - Axis

# %%
# Slicing the resultant dataset for only Running and Walking Activities
Run_Walk2 = Task2Results[((Task2Results['Activity'] == 'Walking') | (Task2Results['Activity'] == 'Running')) & (Task2Results['Signal Length'] == 4096) 
& (Task2Results['Delay'] == 1)]

# Plotting the scatterplot considering X-Axis
sns.relplot(x = 'Permutation Entropy', y = 'Complexity', hue='Activity', row = 'Sensor', col='Dimension', 
            data = Run_Walk2[Run_Walk2['Accelerometer Axis'] == 'x'], height=5)

# %% [markdown]
# ##### Y - Axis

# %%
# Plotting the scatterplot considering Y-Axis
sns.relplot(x = 'Permutation Entropy', y = 'Complexity', hue='Activity', row = 'Sensor', col='Dimension', 
            data = Run_Walk2[Run_Walk2['Accelerometer Axis'] == 'y'], height=5)

# %% [markdown]
# ##### Z - Axis

# %%
# Plotting the scatterplot considering Z-Axis
sns.relplot(x = 'Permutation Entropy', y = 'Complexity', hue='Activity', row = 'Sensor', col='Dimension', 
            data = Run_Walk2[Run_Walk2['Accelerometer Axis'] == 'z'], height=5)

# %% [markdown]
# #### Climbing Up & Climbing Down

# %% [markdown]
# ##### X - Axis

# %%
# Slicing the resultant dataset for only Climbing Up and Climbing Down Activities
ClimbingUp_Down2 = Task2Results[((Task2Results['Activity'] == 'Climbing Up') | (Task2Results['Activity'] == 'Climbing Down')) & (Task2Results['Signal Length'] == 4096) 
& (Task2Results['Delay'] == 1)]

# Plotting the scatterplot considering X-Axis
sns.relplot(x = 'Permutation Entropy', y = 'Complexity', hue='Activity', row = 'Sensor', col='Dimension', 
            data = ClimbingUp_Down2[ClimbingUp_Down2['Accelerometer Axis'] == 'x'], height=5)

# %% [markdown]
# ##### Y - Axis

# %%
# Plotting the scatterplot considering Y-Axis
sns.relplot(x = 'Permutation Entropy', y = 'Complexity', hue='Activity', row = 'Sensor', col='Dimension', 
            data = ClimbingUp_Down2[ClimbingUp_Down2['Accelerometer Axis'] == 'y'], height=5)

# %% [markdown]
# ##### Z - Axis

# %%
# Plotting the scatterplot considering Z-Axis
sns.relplot(x = 'Permutation Entropy', y = 'Complexity', hue='Activity', row = 'Sensor', col='Dimension', 
            data = ClimbingUp_Down2[ClimbingUp_Down2['Accelerometer Axis'] == 'z'], height=5)
